# %%
# INIT IMPORT
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Лабораторная работа 1
# Pandas
#
# Выполнил:  6131 Чаплыгин Алексей Олегович

# %% [markdown]
# 1 Считать в pandas DataFrame любой источник данных:  CSV, JSON, Excel-файл, HTML-таблицу, встроенный датасет sklearn. Опишите ваши данные, что обозначает каждый столбец, какого типа (категориальный, вещественный, целочисленный, бинарный) данный столбец, при необходимости для категориальных в том числе бинарных признаков привести расшифровку их значений. В общем, проведите "визуальный" анализ ваших данных.

# %%
df = pd.read_csv('data/Twitch_game_data.csv', sep=',', encoding='windows-1251')

# %% [markdown]
# Используемый в работе набор данных доступен по следующей ссылке: https://www.kaggle.com/rankirsh/evolution-of-top-games-on-twitch и описывает рейтинг популярных 200 игр, транслируемых на платформе Twitch с 2016 по 2021 года.
# </br>В наборе данных содержится таблица с 12 столбцами, ключевым для метки класса в качестве эксперимента можем взять столбец Year
# </br>
# <table border="1">
#    <caption>Top games on Twitch 2016 - 2021</caption>
#    <tr>
#     <th>Номер столбца</th>
#     <th>Название столбца</th>
#     <th>Описание столбца</th>
#    </tr>
#    <tr><td>1</td><td>Rank</td><td>Значение рейтинга</td></tr>
#    <tr><td>2</td><td>Game</td><td>Наименование игры</td></tr>
#    <tr><td>3</td><td>Month</td><td>Месяц</td></tr>
#    <tr><td>4</td><td>Year</td><td>Год</td></tr>
#    <tr><td>5</td><td>Hours_watched</td><td>Колчествао часов, которое зрители смотрели</td></tr>
#    <tr><td>6</td><td>Hours_Streamed</td><td>Количество часов, которое стримеры стримили</td></tr>
#    <tr><td>7</td><td>Peak_viewers</td><td>Максимальное количество зрителей</td></tr>
#    <tr><td>8</td><td>Peak_channels</td><td>Максимальное количество каналов на которых происходила трансляция одновременно</td></tr>
#    <tr><td>9</td><td>Streamers</td><td>Всего стримеров, которые  стримили эту игру</td></tr>
#    <tr><td>10</td><td>Avg_viewers</td><td>Среднее количество просмотров</td></tr>
#    <tr><td>11</td><td>Avg_channels</td><td>Среднее количество каналов</td></tr>
#    <tr><td>12</td><td>Avg_viewer_ratio</td><td>Средний коэффициент просмотров</td></tr>
#   </table>

# %%
pd.DataFrame([df.columns, df.dtypes], index=['Column Name', 'Column Type'])
# Out:
#                 0       1      2      3              4               5   \
# Column Name   Rank    Game  Month   Year  Hours_watched  Hours_Streamed
# Column Type  int64  object  int64  int64          int64          object
#
#                        6              7          8            9   \
# Column Name  Peak_viewers  Peak_channels  Streamers  Avg_viewers
# Column Type         int64          int64      int64        int64
#
#                        10                11
# Column Name  Avg_channels  Avg_viewer_ratio
# Column Type         int64           float64

# %%
df
# Out:
#        Rank                              Game  Month  Year  Hours_watched  \
# 0         1                 League of Legends      1  2016       94377226
# 1         2  Counter-Strike: Global Offensive      1  2016       47832863
# 2         3                            Dota 2      1  2016       45185893
# 3         4                       Hearthstone      1  2016       39936159
# 4         5       Call of Duty: Black Ops III      1  2016       16153057
# ...     ...                               ...    ...   ...            ...
# 14395   196                       Garry's Mod     12  2021         630902
# 14396   197  Call of Duty: Black Ops Cold War     12  2021         622497
# 14397   198                             Noita     12  2021         620983
# 14398   199                 Pro Soccer Online     12  2021         619859
# 14399   200       Pok<U+00E9>mon Sword/Shield     12  2021         615725
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 0      1362044 hours        530270           2903     129172       127021
# 1       830105 hours        372654           2197     120849        64378
# 2       433397 hours        315083           1100      44074        60815
# 3       235903 hours        131357            517      36170        53749
# 4      1151578 hours         71639           3620     214054        21740
# ...              ...           ...            ...        ...          ...
# 14395    21753 hours         24951             99       3537          849
# 14396   223641 hours         26559            654      25366          837
# 14397    13935 hours         27826             41       1961          835
# 14398      606 hours         36182             20         84          834
# 14399    42291 hours          8878            106       4411          828
#
#        Avg_channels  Avg_viewer_ratio
# 0              1833             69.29
# 1              1117             57.62
# 2               583            104.26
# 3               317            169.29
# 4              1549             14.03
# ...             ...               ...
# 14395            29             29.00
# 14396           300              2.78
# 14397            18             44.56
# 14398             0           1022.87
# 14399            56             14.56
#
# [14400 rows x 12 columns]

# %% [markdown]
# 2 Выполните с датафреймом следующие операции (многие операции можно совершить не одним способом, используйте все известные вам способы, поищите/придумайте новые способы):

# %% [markdown]
# 2.1 вывод таблицы

# %%
df
# Out:
#        Rank                              Game  Month  Year  Hours_watched  \
# 0         1                 League of Legends      1  2016       94377226
# 1         2  Counter-Strike: Global Offensive      1  2016       47832863
# 2         3                            Dota 2      1  2016       45185893
# 3         4                       Hearthstone      1  2016       39936159
# 4         5       Call of Duty: Black Ops III      1  2016       16153057
# ...     ...                               ...    ...   ...            ...
# 14395   196                       Garry's Mod     12  2021         630902
# 14396   197  Call of Duty: Black Ops Cold War     12  2021         622497
# 14397   198                             Noita     12  2021         620983
# 14398   199                 Pro Soccer Online     12  2021         619859
# 14399   200       Pok<U+00E9>mon Sword/Shield     12  2021         615725
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 0      1362044 hours        530270           2903     129172       127021
# 1       830105 hours        372654           2197     120849        64378
# 2       433397 hours        315083           1100      44074        60815
# 3       235903 hours        131357            517      36170        53749
# 4      1151578 hours         71639           3620     214054        21740
# ...              ...           ...            ...        ...          ...
# 14395    21753 hours         24951             99       3537          849
# 14396   223641 hours         26559            654      25366          837
# 14397    13935 hours         27826             41       1961          835
# 14398      606 hours         36182             20         84          834
# 14399    42291 hours          8878            106       4411          828
#
#        Avg_channels  Avg_viewer_ratio
# 0              1833             69.29
# 1              1117             57.62
# 2               583            104.26
# 3               317            169.29
# 4              1549             14.03
# ...             ...               ...
# 14395            29             29.00
# 14396           300              2.78
# 14397            18             44.56
# 14398             0           1022.87
# 14399            56             14.56
#
# [14400 rows x 12 columns]

# %% [markdown]
# 2.2 вывод первых n элементов таблицы

# %%
#Вывод первого
df.iloc[0]
# Out:
# Rank                                1
# Game                League of Legends
# Month                               1
# Year                             2016
# Hours_watched                94377226
# Hours_Streamed          1362044 hours
# Peak_viewers                   530270
# Peak_channels                    2903
# Streamers                      129172
# Avg_viewers                    127021
# Avg_channels                     1833
# Avg_viewer_ratio                69.29
# Name: 0, dtype: object

# %%
#Вывод первых 10
df.head(10)
# Out:
#    Rank                              Game  Month  Year  Hours_watched  \
# 0     1                 League of Legends      1  2016       94377226
# 1     2  Counter-Strike: Global Offensive      1  2016       47832863
# 2     3                            Dota 2      1  2016       45185893
# 3     4                       Hearthstone      1  2016       39936159
# 4     5       Call of Duty: Black Ops III      1  2016       16153057
# 5     6                         Minecraft      1  2016       10231056
# 6     7                 World of Warcraft      1  2016        8771452
# 7     8                 Z1: Battle Royale      1  2016        7894571
# 8     9             Talk Shows & Podcasts      1  2016        7688369
# 9    10                           FIFA 16      1  2016        6988475
#
#   Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 0  1362044 hours        530270           2903     129172       127021
# 1   830105 hours        372654           2197     120849        64378
# 2   433397 hours        315083           1100      44074        60815
# 3   235903 hours        131357            517      36170        53749
# 4  1151578 hours         71639           3620     214054        21740
# 5   490002 hours         64432           1538      88820        13769
# 6   342978 hours         46130           1180      33375        11805
# 7   205569 hours         41588            460      21396        10625
# 8    53235 hours         84051            148      10779        10347
# 9   203646 hours        145728            756      46462         9405
#
#    Avg_channels  Avg_viewer_ratio
# 0          1833             69.29
# 1          1117             57.62
# 2           583            104.26
# 3           317            169.29
# 4          1549             14.03
# 5           659             20.88
# 6           461             25.57
# 7           276             38.40
# 8            71            144.42
# 9           274             34.32

# %%
#Вывод первых 10
data = df[0:10]
print(data)
# Out:
#    Rank                              Game  Month  Year  Hours_watched  \
# 0     1                 League of Legends      1  2016       94377226
# 1     2  Counter-Strike: Global Offensive      1  2016       47832863
# 2     3                            Dota 2      1  2016       45185893
# 3     4                       Hearthstone      1  2016       39936159
# 4     5       Call of Duty: Black Ops III      1  2016       16153057
# 5     6                         Minecraft      1  2016       10231056
# 6     7                 World of Warcraft      1  2016        8771452
# 7     8                 Z1: Battle Royale      1  2016        7894571
# 8     9             Talk Shows & Podcasts      1  2016        7688369
# 9    10                           FIFA 16      1  2016        6988475
#
#   Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 0  1362044 hours        530270           2903     129172       127021
# 1   830105 hours        372654           2197     120849        64378
# 2   433397 hours        315083           1100      44074        60815
# 3   235903 hours        131357            517      36170        53749
# 4  1151578 hours         71639           3620     214054        21740
# 5   490002 hours         64432           1538      88820        13769
# 6   342978 hours         46130           1180      33375        11805
# 7   205569 hours         41588            460      21396        10625
# 8    53235 hours         84051            148      10779        10347
# 9   203646 hours        145728            756      46462         9405
#
#    Avg_channels  Avg_viewer_ratio
# 0          1833             69.29
# 1          1117             57.62
# 2           583            104.26
# 3           317            169.29
# 4          1549             14.03
# 5           659             20.88
# 6           461             25.57
# 7           276             38.40
# 8            71            144.42
# 9           274             34.32

# %% [markdown]
# 2.3 вывод последних n элементов таблицы

# %%
#Вывод последней записи
df.tail(1)
# Out:
#        Rank                         Game  Month  Year  Hours_watched  \
# 14399   200  Pok<U+00E9>mon Sword/Shield     12  2021         615725
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 14399    42291 hours          8878            106       4411          828
#
#        Avg_channels  Avg_viewer_ratio
# 14399            56             14.56

# %%
#Вывод последних 10 записей
df.tail(10)
# Out:
#        Rank                              Game  Month  Year  Hours_watched  \
# 14390   191                         Lineage 2     12  2021         703241
# 14391   192                     The Long Dark     12  2021         688245
# 14392   193                          DNF Duel     12  2021         661281
# 14393   194                             Hades     12  2021         656360
# 14394   195                      Guild Wars 2     12  2021         655625
# 14395   196                       Garry's Mod     12  2021         630902
# 14396   197  Call of Duty: Black Ops Cold War     12  2021         622497
# 14397   198                             Noita     12  2021         620983
# 14398   199                 Pro Soccer Online     12  2021         619859
# 14399   200       Pok<U+00E9>mon Sword/Shield     12  2021         615725
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 14390    50697 hours          2722            192       1523          946
# 14391    23176 hours          9719             62       2486          926
# 14392     8052 hours         48533            465       1712          890
# 14393    47075 hours         27108            141       7287          883
# 14394    37889 hours          5335            118       2610          882
# 14395    21753 hours         24951             99       3537          849
# 14396   223641 hours         26559            654      25366          837
# 14397    13935 hours         27826             41       1961          835
# 14398      606 hours         36182             20         84          834
# 14399    42291 hours          8878            106       4411          828
#
#        Avg_channels  Avg_viewer_ratio
# 14390            68             13.87
# 14391            31             29.70
# 14392            10             82.13
# 14393            63             13.94
# 14394            50             17.30
# 14395            29             29.00
# 14396           300              2.78
# 14397            18             44.56
# 14398             0           1022.87
# 14399            56             14.56

# %% [markdown]
# 2.4 .describe() - Статистика по данным

# %%
df.describe()
# Out:
#               Rank         Month          Year  Hours_watched  Peak_viewers  \
# count  14400.00000  14400.000000  14400.000000   1.440000e+04  1.440000e+04
# mean     100.50000      6.500000   2018.500000   4.782448e+06  5.509512e+04
# std       57.73631      3.452172      1.707884   1.667895e+07  1.329134e+05
# min        1.00000      1.000000   2016.000000   8.981100e+04  4.410000e+02
# 25%       50.75000      3.750000   2017.000000   3.680565e+05  8.352500e+03
# 50%      100.50000      6.500000   2018.500000   8.198695e+05  2.016950e+04
# 75%      150.25000      9.250000   2020.000000   2.295376e+06  4.598150e+04
# max      200.00000     12.000000   2021.000000   3.445520e+08  3.123208e+06
#
#        Peak_channels     Streamers    Avg_viewers  Avg_channels  \
# count   14400.000000  1.440000e+04   14400.000000  14400.000000
# mean      586.759236  1.722478e+04    6553.785278    214.859097
# std      2721.411089  5.453153e+04   22858.599426    743.850310
# min         1.000000  0.000000e+00     120.000000      0.000000
# 25%        51.750000  1.479500e+03     504.000000     16.000000
# 50%       122.000000  4.126000e+03    1125.000000     43.000000
# 75%       318.000000  1.071425e+04    3158.000000    121.000000
# max    129860.000000  1.013029e+06  479209.000000  13789.000000
#
#        Avg_viewer_ratio
# count      14400.000000
# mean          81.874403
# std          368.878411
# min            1.950000
# 25%           16.120000
# 50%           29.160000
# 75%           57.795000
# max        13601.870000

# %% [markdown]
# 2.5 считывание значения конкретной ячейки (с конкретным индексом из конкретной колонки)  всеми известными вам способами

# %%
df.loc[0, 'Game']
# Out:
# 'League of Legends'

# %%
df.loc[0][1]
# Out:
# 'League of Legends'

# %%
df.iloc[0, 1]
# Out:
# 'League of Legends'

# %% [markdown]
# 2.6 фильтрация строк по диапазону индекса

# %%
df.take(slice(10, 20))
# Out:
#     Rank                            Game  Month  Year  Hours_watched  \
# 10    11                    StarCraft II      1  2016        6567126
# 11    12                      Diablo III      1  2016        6235668
# 12    13                         Destiny      1  2016        5892573
# 13    14                    Blade & Soul      1  2016        5270251
# 14    15                  World of Tanks      1  2016        4993627
# 15    16  Tom Clancy's Rainbow Six Siege      1  2016        4866039
# 16    17                       RuneScape      1  2016        4632857
# 17    18       Tom Clancy's The Division      1  2016        4495935
# 18    19              Grand Theft Auto V      1  2016        4014296
# 19    20                           SMITE      1  2016        3788701
#
#    Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 10    73753 hours         60355            178       7133         8838
# 11   218490 hours         57383           2185      25458         8392
# 12   551615 hours         18783           1741      60340         7930
# 13   184279 hours         67256           1099      22637         7093
# 14   128356 hours         39358            368      16121         6720
# 15   242134 hours         25742            694      42244         6549
# 16    74628 hours         18809            167       7628         6235
# 17    61799 hours        148710           2008      28361         6051
# 18   407172 hours         32724           1197      85441         5402
# 19   114041 hours         70542            296      15389         5099
#
#     Avg_channels  Avg_viewer_ratio
# 10            99             89.04
# 11           294             28.54
# 12           742             10.68
# 13           248             28.60
# 14           172             38.90
# 15           325             20.10
# 16           100             62.08
# 17            83             72.75
# 18           548              9.86
# 19           153             33.22

# %%
df.loc[10:20]
# Out:
#     Rank                            Game  Month  Year  Hours_watched  \
# 10    11                    StarCraft II      1  2016        6567126
# 11    12                      Diablo III      1  2016        6235668
# 12    13                         Destiny      1  2016        5892573
# 13    14                    Blade & Soul      1  2016        5270251
# 14    15                  World of Tanks      1  2016        4993627
# 15    16  Tom Clancy's Rainbow Six Siege      1  2016        4866039
# 16    17                       RuneScape      1  2016        4632857
# 17    18       Tom Clancy's The Division      1  2016        4495935
# 18    19              Grand Theft Auto V      1  2016        4014296
# 19    20                           SMITE      1  2016        3788701
# 20    21                        Creative      1  2016        3181207
#
#    Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 10    73753 hours         60355            178       7133         8838
# 11   218490 hours         57383           2185      25458         8392
# 12   551615 hours         18783           1741      60340         7930
# 13   184279 hours         67256           1099      22637         7093
# 14   128356 hours         39358            368      16121         6720
# 15   242134 hours         25742            694      42244         6549
# 16    74628 hours         18809            167       7628         6235
# 17    61799 hours        148710           2008      28361         6051
# 18   407172 hours         32724           1197      85441         5402
# 19   114041 hours         70542            296      15389         5099
# 20   119776 hours         69027            310      15551         4281
#
#     Avg_channels  Avg_viewer_ratio
# 10            99             89.04
# 11           294             28.54
# 12           742             10.68
# 13           248             28.60
# 14           172             38.90
# 15           325             20.10
# 16           100             62.08
# 17            83             72.75
# 18           548              9.86
# 19           153             33.22
# 20           161             26.56

# %%
df.loc[10:20:5]
# Out:
#     Rank                            Game  Month  Year  Hours_watched  \
# 10    11                    StarCraft II      1  2016        6567126
# 15    16  Tom Clancy's Rainbow Six Siege      1  2016        4866039
# 20    21                        Creative      1  2016        3181207
#
#    Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 10    73753 hours         60355            178       7133         8838
# 15   242134 hours         25742            694      42244         6549
# 20   119776 hours         69027            310      15551         4281
#
#     Avg_channels  Avg_viewer_ratio
# 10            99             89.04
# 15           325             20.10
# 20           161             26.56

# %% [markdown]
# 2.7 фильтрация набора данных по какому-либо условию

# %%
df.loc[df['Game'] == 'Diablo III'].head(12)
# Out:
#       Rank        Game  Month  Year  Hours_watched Hours_Streamed  \
# 11      12  Diablo III      1  2016        6235668   218490 hours
# 224     25  Diablo III      2  2016        2737755   117265 hours
# 455     56  Diablo III      3  2016         840299    57510 hours
# 639     40  Diablo III      4  2016        1249251    68153 hours
# 824     25  Diablo III      5  2016        3170002   138365 hours
# 1049    50  Diablo III      6  2016         758911    50876 hours
# 1284    85  Diablo III      7  2016         391823    32464 hours
# 1429    30  Diablo III      8  2016        1871918   101238 hours
# 1699   100  Diablo III      9  2016         255656    35077 hours
# 1874    75  Diablo III     10  2016         449332    49080 hours
# 2071    72  Diablo III     11  2016         568632    61382 hours
# 2291    92  Diablo III     12  2016         446884    41455 hours
#
#       Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 11           57383           2185      25458         8392           294
# 224          28509            344      15718         3939           168
# 455           4634            158       8647         1130            77
# 639          25553           1323       9790         1737            94
# 824          17247            600      16427         4266           186
# 1049          3724            151       7536         1055            70
# 1284         16494             90       6030          527            43
# 1429         28044            805      11915         2519           136
# 1699          1482            102       6358          355            48
# 1874          7685            415       6932          604            66
# 2071          9764            159       8076          790            85
# 2291          3340            109       1740          601            55
#
#       Avg_viewer_ratio
# 11               28.54
# 224              23.35
# 455              14.61
# 639              18.33
# 824              22.91
# 1049             14.92
# 1284             12.07
# 1429             18.49
# 1699              7.29
# 1874              9.16
# 2071              9.26
# 2291             10.78

# %%
df["Game"].str.contains("League")
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14395    False
# 14396    False
# 14397    False
# 14398    False
# 14399    False
# Name: Game, Length: 14400, dtype: object

# %%
df.query('Game == "Diablo III"')
# Out:
#        Rank        Game  Month  Year  Hours_watched Hours_Streamed  \
# 11       12  Diablo III      1  2016        6235668   218490 hours
# 224      25  Diablo III      2  2016        2737755   117265 hours
# 455      56  Diablo III      3  2016         840299    57510 hours
# 639      40  Diablo III      4  2016        1249251    68153 hours
# 824      25  Diablo III      5  2016        3170002   138365 hours
# ...     ...         ...    ...   ...            ...            ...
# 12652    53  Diablo III      4  2021        4331609   179334 hours
# 12981   182  Diablo III      5  2021         898831    63632 hours
# 13274    75  Diablo III      7  2021        2638720    83475 hours
# 13497    98  Diablo III      8  2021        2370875   102371 hours
# 14261    62  Diablo III     12  2021        3910409    89586 hours
#
#        Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 11            57383           2185      25458         8392           294
# 224           28509            344      15718         3939           168
# 455            4634            158       8647         1130            77
# 639           25553           1323       9790         1737            94
# 824           17247            600      16427         4266           186
# ...             ...            ...        ...          ...           ...
# 12652         50930           1605      15191         6024           249
# 12981         32712            195       6113         1209            85
# 13274         30286            899       7451         3551           112
# 13497         14283            283       8734         3190           137
# 14261         39145            766       6581         5263           120
#
#        Avg_viewer_ratio
# 11                28.54
# 224               23.35
# 455               14.61
# 639               18.33
# 824               22.91
# ...                 ...
# 12652             24.15
# 12981             14.13
# 13274             31.61
# 13497             23.16
# 14261             43.65
#
# [67 rows x 12 columns]

# %% [markdown]
# 2.8. работа с пропущенными значениями (если они есть): удаление строк с пропущенными значениями, заполнение пропущенных значений средним значением по колонке. Если пропущенных значений нет — намеренно их "генерируете", прибивая какие-то куски данных в np.nan

# %%
nan_df = df.copy()

# %%
nan_df = nan_df.replace(2016, np.NAN)
nan_df
# Out:
#        Rank                              Game  Month    Year  Hours_watched  \
# 0         1                 League of Legends      1     NaN       94377226
# 1         2  Counter-Strike: Global Offensive      1     NaN       47832863
# 2         3                            Dota 2      1     NaN       45185893
# 3         4                       Hearthstone      1     NaN       39936159
# 4         5       Call of Duty: Black Ops III      1     NaN       16153057
# ...     ...                               ...    ...     ...            ...
# 14395   196                       Garry's Mod     12  2021.0         630902
# 14396   197  Call of Duty: Black Ops Cold War     12  2021.0         622497
# 14397   198                             Noita     12  2021.0         620983
# 14398   199                 Pro Soccer Online     12  2021.0         619859
# 14399   200       Pok<U+00E9>mon Sword/Shield     12  2021.0         615725
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 0      1362044 hours      530270.0           2903   129172.0     127021.0
# 1       830105 hours      372654.0           2197   120849.0      64378.0
# 2       433397 hours      315083.0           1100    44074.0      60815.0
# 3       235903 hours      131357.0            517    36170.0      53749.0
# 4      1151578 hours       71639.0           3620   214054.0      21740.0
# ...              ...           ...            ...        ...          ...
# 14395    21753 hours       24951.0             99     3537.0        849.0
# 14396   223641 hours       26559.0            654    25366.0        837.0
# 14397    13935 hours       27826.0             41     1961.0        835.0
# 14398      606 hours       36182.0             20       84.0        834.0
# 14399    42291 hours        8878.0            106     4411.0        828.0
#
#        Avg_channels  Avg_viewer_ratio
# 0              1833             69.29
# 1              1117             57.62
# 2               583            104.26
# 3               317            169.29
# 4              1549             14.03
# ...             ...               ...
# 14395            29             29.00
# 14396           300              2.78
# 14397            18             44.56
# 14398             0           1022.87
# 14399            56             14.56
#
# [14400 rows x 12 columns]

# %%
nan_df.fillna(666).head(1)
# Out:
#    Rank               Game  Month   Year  Hours_watched Hours_Streamed  \
# 0     1  League of Legends      1  666.0       94377226  1362044 hours
#
#    Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 0      530270.0           2903   129172.0     127021.0          1833
#
#    Avg_viewer_ratio
# 0             69.29

# %%
nan_df.loc[0:20:2]= np.NaN
nan_df
# Out:
#         Rank                              Game  Month    Year  Hours_watched  \
# 0        NaN                               NaN    NaN     NaN            NaN
# 1        2.0  Counter-Strike: Global Offensive    1.0     NaN     47832863.0
# 2        NaN                               NaN    NaN     NaN            NaN
# 3        4.0                       Hearthstone    1.0     NaN     39936159.0
# 4        NaN                               NaN    NaN     NaN            NaN
# ...      ...                               ...    ...     ...            ...
# 14395  196.0                       Garry's Mod   12.0  2021.0       630902.0
# 14396  197.0  Call of Duty: Black Ops Cold War   12.0  2021.0       622497.0
# 14397  198.0                             Noita   12.0  2021.0       620983.0
# 14398  199.0                 Pro Soccer Online   12.0  2021.0       619859.0
# 14399  200.0       Pok<U+00E9>mon Sword/Shield   12.0  2021.0       615725.0
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 0                NaN           NaN            NaN        NaN          NaN
# 1       830105 hours      372654.0         2197.0   120849.0      64378.0
# 2                NaN           NaN            NaN        NaN          NaN
# 3       235903 hours      131357.0          517.0    36170.0      53749.0
# 4                NaN           NaN            NaN        NaN          NaN
# ...              ...           ...            ...        ...          ...
# 14395    21753 hours       24951.0           99.0     3537.0        849.0
# 14396   223641 hours       26559.0          654.0    25366.0        837.0
# 14397    13935 hours       27826.0           41.0     1961.0        835.0
# 14398      606 hours       36182.0           20.0       84.0        834.0
# 14399    42291 hours        8878.0          106.0     4411.0        828.0
#
#        Avg_channels  Avg_viewer_ratio
# 0               NaN               NaN
# 1            1117.0             57.62
# 2               NaN               NaN
# 3             317.0            169.29
# 4               NaN               NaN
# ...             ...               ...
# 14395          29.0             29.00
# 14396         300.0              2.78
# 14397          18.0             44.56
# 14398           0.0           1022.87
# 14399          56.0             14.56
#
# [14400 rows x 12 columns]

# %%
# удаляем пропуски
clear_nan_df = nan_df['Year'].dropna()
clear_nan_df
# Out:
# 2400     2017.0
# 2401     2017.0
# 2402     2017.0
# 2403     2017.0
# 2404     2017.0
#           ...
# 14395    2021.0
# 14396    2021.0
# 14397    2021.0
# 14398    2021.0
# 14399    2021.0
# Name: Year, Length: 12000, dtype: float64

# %% [markdown]
# 2.9. создание нового поля вычисленного на основе значений других полей:
# 2.9.1 через выражение на базе имеющихся колонок,

# %%
df['Game Copy'] = df['Game']
df.head(1).T
# Out:
#                                   0
# Rank                              1
# Game              League of Legends
# Month                             1
# Year                           2016
# Hours_watched              94377226
# Hours_Streamed        1362044 hours
# Peak_viewers                 530270
# Peak_channels                  2903
# Streamers                    129172
# Avg_viewers                  127021
# Avg_channels                   1833
# Avg_viewer_ratio              69.29
# Game Copy         League of Legends

# %% [markdown]
# 2.9.2 через DataFrame.apply

# %%
df['Hours_Streamed Copy'] = df.apply(lambda x: x['Hours_Streamed'].replace(' hours', '') , axis=1)
df.head(1).T
# Out:
#                                      0
# Rank                                 1
# Game                 League of Legends
# Month                                1
# Year                              2016
# Hours_watched                 94377226
# Hours_Streamed           1362044 hours
# Peak_viewers                    530270
# Peak_channels                     2903
# Streamers                       129172
# Avg_viewers                     127021
# Avg_channels                      1833
# Avg_viewer_ratio                 69.29
# Game Copy            League of Legends
# Hours_Streamed Copy            1362044

# %% [markdown]
# 2.9.3 через Series.apply

# %%
df['Lenght Game Name'] = df['Game'].apply(lambda x: len(str(x)))
df
# Out:
#        Rank                              Game  Month  Year  Hours_watched  \
# 0         1                 League of Legends      1  2016       94377226
# 1         2  Counter-Strike: Global Offensive      1  2016       47832863
# 2         3                            Dota 2      1  2016       45185893
# 3         4                       Hearthstone      1  2016       39936159
# 4         5       Call of Duty: Black Ops III      1  2016       16153057
# ...     ...                               ...    ...   ...            ...
# 14395   196                       Garry's Mod     12  2021         630902
# 14396   197  Call of Duty: Black Ops Cold War     12  2021         622497
# 14397   198                             Noita     12  2021         620983
# 14398   199                 Pro Soccer Online     12  2021         619859
# 14399   200       Pok<U+00E9>mon Sword/Shield     12  2021         615725
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 0      1362044 hours        530270           2903     129172       127021
# 1       830105 hours        372654           2197     120849        64378
# 2       433397 hours        315083           1100      44074        60815
# 3       235903 hours        131357            517      36170        53749
# 4      1151578 hours         71639           3620     214054        21740
# ...              ...           ...            ...        ...          ...
# 14395    21753 hours         24951             99       3537          849
# 14396   223641 hours         26559            654      25366          837
# 14397    13935 hours         27826             41       1961          835
# 14398      606 hours         36182             20         84          834
# 14399    42291 hours          8878            106       4411          828
#
#        Avg_channels  Avg_viewer_ratio                         Game Copy  \
# 0              1833             69.29                 League of Legends
# 1              1117             57.62  Counter-Strike: Global Offensive
# 2               583            104.26                            Dota 2
# 3               317            169.29                       Hearthstone
# 4              1549             14.03       Call of Duty: Black Ops III
# ...             ...               ...                               ...
# 14395            29             29.00                       Garry's Mod
# 14396           300              2.78  Call of Duty: Black Ops Cold War
# 14397            18             44.56                             Noita
# 14398             0           1022.87                 Pro Soccer Online
# 14399            56             14.56       Pok<U+00E9>mon Sword/Shield
#
#       Hours_Streamed Copy  Lenght Game Name
# 0                 1362044                17
# 1                  830105                32
# 2                  433397                 6
# 3                  235903                11
# 4                 1151578                27
# ...                   ...               ...
# 14395               21753                11
# 14396              223641                32
# 14397               13935                 5
# 14398                 606                17
# 14399               42291                27
#
# [14400 rows x 15 columns]

# %% [markdown]
# 2.10 сортировка по какому-либо из полей

# %%
df.fillna(0).sort_values('Rank', ascending=False).head(5)
# Out:
#        Rank                         Game  Month  Year  Hours_watched  \
# 14399   200  Pok<U+00E9>mon Sword/Shield     12  2021         615725
# 10399   200                      FIFA 17      4  2020         446780
# 11199   200             ShootMania Storm      8  2020         482392
# 10999   200         Kingdom of the Winds      7  2020         523740
# 10799   200                 Shadow Arena      6  2020         480029
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 14399    42291 hours          8878            106       4411          828
# 10399     5129 hours          3303             14        252          621
# 11199      748 hours        147354             40        118          649
# 10999     5109 hours         19219             39        315          704
# 10799     7033 hours         21156             26        742          667
#
#        Avg_channels  Avg_viewer_ratio                    Game Copy  \
# 14399            56             14.56  Pok<U+00E9>mon Sword/Shield
# 10399             7             87.11                      FIFA 17
# 11199             1            644.91             ShootMania Storm
# 10999             6            102.51         Kingdom of the Winds
# 10799             9             68.25                 Shadow Arena
#
#       Hours_Streamed Copy  Lenght Game Name
# 14399               42291                27
# 10399                5129                 7
# 11199                 748                16
# 10999                5109                20
# 10799                7033                12

# %% [markdown]
# 2.11 вычислить несколько статистик по колонкам (используйте встроенные агрегатные функции — любые на выбор)

# %%
df['Hours_watched'].min(), df['Hours_Streamed'].max(), df['Hours_Streamed Copy'].max(), df['Hours_Streamed Copy'].min(), df['Avg_viewer_ratio'].mean(), df['Streamers'].std()
# Out:
# (89811, '99994 hours', '99994', '100', 81.87440277777777, 54531.52640693918)

# %% [markdown]
# 2.12 .value_counts()

# %%
df.value_counts()
# Out:
# Rank  Game                               Month  Year  Hours_watched  Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  Avg_viewer_ratio  Game Copy                          Hours_Streamed Copy  Lenght Game Name
# 1     Apex Legends                       2      2019  123090969      5580337 hours   666868        18932          663781     183444       8316          22.06             Apex Legends                       5580337              12                  1
# 135   Halo: The Master Chief Collection  11     2018  431482         21280 hours     12426         117            3347       600          29            20.28             Halo: The Master Chief Collection  21280                33                  1
# 134   FTL: Faster Than Light             4      2017  231669         3901 hours      2888          15             630        322          5             59.39             FTL: Faster Than Light             3901                 22                  1
#                                          5      2016  157367         2929 hours      2837          15             677        211          3             53.73             FTL: Faster Than Light             2929                 22                  1
#                                          10     2017  291074         4463 hours      7640          17             894        391          6             65.22             FTL: Faster Than Light             4463                 22                  1
#                                                                                                                                                                                                                                                      ..
# 67    Special Events                     10     2019  1170252        15177 hours     83753         47             2425       1575         20            77.11             Special Events                     15177                14                  1
#       Street Fighter V                   11     2019  1241838        26515 hours     34624         76             2967       1727         36            46.84             Street Fighter V                   26515                16                  1
#       Summoners War: Sky Arena           2      2017  725167         15055 hours     8989          51             971        1080         22            48.17             Summoners War: Sky Arena           15055                24                  1
#                                          3      2017  710898         14247 hours     9414          53             859        956          19            49.90             Summoners War: Sky Arena           14247                24                  1
# 200   some some convenience store        1      2020  342876         4683 hours      9903          63             800        461          6             73.22             some some convenience store        4683                 27                  1
# Length: 14399, dtype: int64

# %% [markdown]
# 2.13 Вывод уникальных значений колонки через .unique()

# %%
df['Avg_viewer_ratio'].unique()
# Out:
# array([  69.29,   57.62,  104.26, ...,    2.78,   44.56, 1022.87])

# %% [markdown]
# 2.14 Удалите текущий индекс и создайте новый индекс на базе новой колонки, которая для этого лучше всего подходит

# %%
new_df = df.copy()
new_df.index = new_df['Avg_viewer_ratio']
new_df
# Out:
#                   Rank                              Game  Month  Year  \
# Avg_viewer_ratio
# 69.29                1                 League of Legends      1  2016
# 57.62                2  Counter-Strike: Global Offensive      1  2016
# 104.26               3                            Dota 2      1  2016
# 169.29               4                       Hearthstone      1  2016
# 14.03                5       Call of Duty: Black Ops III      1  2016
# ...                ...                               ...    ...   ...
# 29.00              196                       Garry's Mod     12  2021
# 2.78               197  Call of Duty: Black Ops Cold War     12  2021
# 44.56              198                             Noita     12  2021
# 1022.87            199                 Pro Soccer Online     12  2021
# 14.56              200       Pok<U+00E9>mon Sword/Shield     12  2021
#
#                   Hours_watched Hours_Streamed  Peak_viewers  Peak_channels  \
# Avg_viewer_ratio
# 69.29                  94377226  1362044 hours        530270           2903
# 57.62                  47832863   830105 hours        372654           2197
# 104.26                 45185893   433397 hours        315083           1100
# 169.29                 39936159   235903 hours        131357            517
# 14.03                  16153057  1151578 hours         71639           3620
# ...                         ...            ...           ...            ...
# 29.00                    630902    21753 hours         24951             99
# 2.78                     622497   223641 hours         26559            654
# 44.56                    620983    13935 hours         27826             41
# 1022.87                  619859      606 hours         36182             20
# 14.56                    615725    42291 hours          8878            106
#
#                   Streamers  Avg_viewers  Avg_channels  Avg_viewer_ratio  \
# Avg_viewer_ratio
# 69.29                129172       127021          1833             69.29
# 57.62                120849        64378          1117             57.62
# 104.26                44074        60815           583            104.26
# 169.29                36170        53749           317            169.29
# 14.03                214054        21740          1549             14.03
# ...                     ...          ...           ...               ...
# 29.00                  3537          849            29             29.00
# 2.78                  25366          837           300              2.78
# 44.56                  1961          835            18             44.56
# 1022.87                  84          834             0           1022.87
# 14.56                  4411          828            56             14.56
#
#                                          Game Copy Hours_Streamed Copy  \
# Avg_viewer_ratio
# 69.29                            League of Legends             1362044
# 57.62             Counter-Strike: Global Offensive              830105
# 104.26                                      Dota 2              433397
# 169.29                                 Hearthstone              235903
# 14.03                  Call of Duty: Black Ops III             1151578
# ...                                            ...                 ...
# 29.00                                  Garry's Mod               21753
# 2.78              Call of Duty: Black Ops Cold War              223641
# 44.56                                        Noita               13935
# 1022.87                          Pro Soccer Online                 606
# 14.56                  Pok<U+00E9>mon Sword/Shield               42291
#
#                   Lenght Game Name
# Avg_viewer_ratio
# 69.29                           17
# 57.62                           32
# 104.26                           6
# 169.29                          11
# 14.03                           27
# ...                            ...
# 29.00                           11
# 2.78                            32
# 44.56                            5
# 1022.87                         17
# 14.56                           27
#
# [14400 rows x 15 columns]

# %% [markdown]
# 3 Продемонстрировать работу .groupby, на основе группировок в groupby вычисляете агрегатные функции по одной или нескольким колонкам. Какую информацию о данных вы получили, выполнив данную операцию? Запишите ответ в комментариях.

# %%
df.groupby('Year').count()
# Out:
#       Rank  Game  Month  Hours_watched  Hours_Streamed  Peak_viewers  \
# Year
# 2016  2400  2400   2400           2400            2400          2400
# 2017  2400  2400   2400           2400            2400          2400
# 2018  2400  2400   2400           2400            2400          2400
# 2019  2400  2399   2400           2400            2400          2400
# 2020  2400  2400   2400           2400            2400          2400
# 2021  2400  2400   2400           2400            2400          2400
#
#       Peak_channels  Streamers  Avg_viewers  Avg_channels  Avg_viewer_ratio  \
# Year
# 2016           2400       2400         2400          2400              2400
# 2017           2400       2400         2400          2400              2400
# 2018           2400       2400         2400          2400              2400
# 2019           2400       2400         2400          2400              2400
# 2020           2400       2400         2400          2400              2400
# 2021           2400       2400         2400          2400              2400
#
#       Game Copy  Hours_Streamed Copy  Lenght Game Name
# Year
# 2016       2400                 2400              2400
# 2017       2400                 2400              2400
# 2018       2400                 2400              2400
# 2019       2399                 2400              2400
# 2020       2400                 2400              2400
# 2021       2400                 2400              2400

# %% [markdown]
# 4 Решейпинг данных 1Dto2D с помощью .pivot (можно подать на вход результаты агрегатов, полученных ранее через .groupby (сгруппировать по двум полям), либо прекрасно заходит сюда данные из SQL сгруппированные предварительно по 2-м полям). Какую информацию о данных вы получили, выполнив данную операцию? Запишите ответ в комментариях.

# %%
df.groupby('Game').mean().pivot(columns='Avg_viewer_ratio', values='Avg_viewer_ratio')
# Out:
# Avg_viewer_ratio             2.552667      3.530000      3.880000      \
# Game
# .hack//G.U. Last Recode               NaN           NaN           NaN
# 60 Parsecs!                           NaN           NaN           NaN
# 60 Seconds!                           NaN           NaN           NaN
# 7 Days to Die                         NaN           NaN           NaN
# <U+014C>kami                          NaN           NaN           NaN
# ...                                   ...           ...           ...
# osu!                                  NaN           NaN           NaN
# rFactor 2                             NaN           NaN           NaN
# skribbl.io                            NaN           NaN           NaN
# some some convenience store           NaN           NaN           NaN
# theHunter: Call of the Wild           NaN           NaN           NaN
#
# Avg_viewer_ratio             4.120000      4.850000      4.915000      \
# Game
# .hack//G.U. Last Recode              4.12           NaN           NaN
# 60 Parsecs!                           NaN           NaN           NaN
# 60 Seconds!                           NaN           NaN           NaN
# 7 Days to Die                         NaN           NaN           NaN
# <U+014C>kami                          NaN           NaN           NaN
# ...                                   ...           ...           ...
# osu!                                  NaN           NaN           NaN
# rFactor 2                             NaN           NaN           NaN
# skribbl.io                            NaN           NaN           NaN
# some some convenience store           NaN           NaN           NaN
# theHunter: Call of the Wild           NaN           NaN           NaN
#
# Avg_viewer_ratio             4.960000      5.444444      5.640833      \
# Game
# .hack//G.U. Last Recode               NaN           NaN           NaN
# 60 Parsecs!                           NaN           NaN           NaN
# 60 Seconds!                           NaN           NaN           NaN
# 7 Days to Die                         NaN           NaN           NaN
# <U+014C>kami                          NaN           NaN           NaN
# ...                                   ...           ...           ...
# osu!                                  NaN           NaN           NaN
# rFactor 2                             NaN           NaN           NaN
# skribbl.io                            NaN           NaN           NaN
# some some convenience store           NaN           NaN           NaN
# theHunter: Call of the Wild           NaN           NaN           NaN
#
# Avg_viewer_ratio             5.670000      ...  5985.200000   7420.930000   \
# Game                                       ...
# .hack//G.U. Last Recode               NaN  ...           NaN           NaN
# 60 Parsecs!                           NaN  ...           NaN           NaN
# 60 Seconds!                           NaN  ...           NaN           NaN
# 7 Days to Die                         NaN  ...           NaN           NaN
# <U+014C>kami                          NaN  ...           NaN           NaN
# ...                                   ...  ...           ...           ...
# osu!                                  NaN  ...           NaN           NaN
# rFactor 2                             NaN  ...           NaN           NaN
# skribbl.io                            NaN  ...           NaN           NaN
# some some convenience store           NaN  ...           NaN           NaN
# theHunter: Call of the Wild           NaN  ...           NaN           NaN
#
# Avg_viewer_ratio             7675.030000   8688.240000   8712.070000   \
# Game
# .hack//G.U. Last Recode               NaN           NaN           NaN
# 60 Parsecs!                           NaN           NaN           NaN
# 60 Seconds!                           NaN           NaN           NaN
# 7 Days to Die                         NaN           NaN           NaN
# <U+014C>kami                          NaN           NaN           NaN
# ...                                   ...           ...           ...
# osu!                                  NaN           NaN           NaN
# rFactor 2                             NaN           NaN           NaN
# skribbl.io                            NaN           NaN           NaN
# some some convenience store           NaN           NaN           NaN
# theHunter: Call of the Wild           NaN           NaN           NaN
#
# Avg_viewer_ratio             9105.840000   9439.390000   9539.540000   \
# Game
# .hack//G.U. Last Recode               NaN           NaN           NaN
# 60 Parsecs!                           NaN           NaN           NaN
# 60 Seconds!                           NaN           NaN           NaN
# 7 Days to Die                         NaN           NaN           NaN
# <U+014C>kami                          NaN           NaN           NaN
# ...                                   ...           ...           ...
# osu!                                  NaN           NaN           NaN
# rFactor 2                             NaN           NaN           NaN
# skribbl.io                            NaN           NaN           NaN
# some some convenience store           NaN           NaN           NaN
# theHunter: Call of the Wild           NaN           NaN           NaN
#
# Avg_viewer_ratio             10783.080000  11457.470000
# Game
# .hack//G.U. Last Recode               NaN           NaN
# 60 Parsecs!                           NaN           NaN
# 60 Seconds!                           NaN           NaN
# 7 Days to Die                         NaN           NaN
# <U+014C>kami                          NaN           NaN
# ...                                   ...           ...
# osu!                                  NaN           NaN
# rFactor 2                             NaN           NaN
# skribbl.io                            NaN           NaN
# some some convenience store           NaN           NaN
# theHunter: Call of the Wild           NaN           NaN
#
# [1799 rows x 1779 columns]

# %% [markdown]
# 5 Решейпинг 1Dto2D данных соединённый с группировкой / агрегацией (одним словом — сводная таблица): .pivot_table. Группируем только по категориальным полям или числовым, если уверены, что значений немного! Если значений много, можете вначале из загрубить (см. (2.9.) либо (7)).
# Перед тем как выполнять задание сформулируйте вопрос, на который собираетесь получить ответ с помощью сводной таблицы. Запишите этот вопрос в комментариях. Какую информацию о данных вы в результате получили?</br>
# https://pbpython.com/pandas-pivot-table-explained.html</br>
#
# Посмотрть есть снижение коэффициента досмотра стримов в последнее время?

# %%
pd.pivot_table(df, index='Avg_viewer_ratio')
# Out:
#                   Avg_channels  Avg_viewers  Hours_watched  Lenght Game Name  \
# Avg_viewer_ratio
# 1.95                    2170.0       4225.0      3139259.0              28.0
# 1.98                    2906.0       5759.0      4140782.0              28.0
# 2.27                    6659.0      15098.0     11218009.0              28.0
# 2.29                    7096.0      16271.0     10918065.0              28.0
# 2.32                    4780.0      11075.0      7963312.0              28.0
# ...                        ...          ...            ...               ...
# 9439.39                    0.0        355.0       264303.0               8.0
# 9539.54                    0.0        873.0       648689.0              35.0
# 10783.08                   0.0        362.0       269577.0              17.0
# 11457.47                   0.0        292.0       217692.0               9.0
# 13601.87                   0.0        695.0       516871.0              15.0
#
#                   Month  Peak_channels  Peak_viewers   Rank  Streamers    Year
# Avg_viewer_ratio
# 1.95               12.0         5541.0       33616.0   71.0   138571.0  2021.0
# 1.98               11.0         6219.0       29529.0   57.0   164882.0  2021.0
# 2.27                1.0        13547.0       41712.0   29.0   362233.0  2021.0
# 2.29                2.0        13827.0       48998.0   30.0   363852.0  2021.0
# 2.32                6.0         9033.0       63836.0   30.0   260049.0  2021.0
# ...                 ...            ...           ...    ...        ...     ...
# 9439.39             7.0            1.0       29021.0  130.0        2.0  2016.0
# 9539.54            10.0            2.0       92496.0  199.0       18.0  2021.0
# 10783.08            7.0           10.0      120714.0  191.0       14.0  2018.0
# 11457.47            1.0           10.0      153550.0  198.0       12.0  2017.0
# 13601.87            7.0            2.0       22125.0  119.0        4.0  2019.0
#
# [7492 rows x 10 columns]

# %% [markdown]
# 6 Посчитать квантили распределения какого-либо вещественного признака (с помощью numpy.quantile или numpy.percentile)

# %%
np.quantile(df['Avg_viewer_ratio'].fillna(0), 0.5)
# Out:
# 29.16

# %%
df.quantile(0.5, numeric_only=True)
# Out:
# Rank                   100.50
# Month                    6.50
# Year                  2018.50
# Hours_watched       819869.50
# Peak_viewers         20169.50
# Peak_channels          122.00
# Streamers             4126.00
# Avg_viewers           1125.00
# Avg_channels            43.00
# Avg_viewer_ratio        29.16
# Lenght Game Name        14.00
# Name: 0.5, dtype: float64

# %% [markdown]
# 7 Посчитать гистограмму какого-либо вещественного признака (с помощью numpy.histogram). Значения гистограммы можете использовать как вариант в качестве загрубленного числового признака для заданий (4) или (5).

# %%
plt.hist(data['Avg_viewer_ratio'])
# Out:
# (array([3., 2., 1., 1., 0., 1., 0., 0., 1., 1.]),
#  array([ 14.03 ,  29.556,  45.082,  60.608,  76.134,  91.66 , 107.186,
#         122.712, 138.238, 153.764, 169.29 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 8 Получить DataFrame с MultiIndex любым способом: через конструктор (в документации увидите множество видов конструкторов для создания MultiIndex с нуля), через read_sql / read_csv / read_excel, read_*, через pivot_table, через groupby или иными способами.

# %% [raw]
# multi_indexed_data = df.groupby(['Game', 'Avg_viewer_ratio']).mean()
# multi_indexed_data.head()

# %% [markdown]
# 9 Переставить местами уровни индекса

# %%
multi_indexed_data.swaplevel().sort_index().head()
# Out:
#                                                Rank  Month    Year  \
# Avg_viewer_ratio Game
# 1.95             Call Of Duty: Modern Warfare  71.0   12.0  2021.0
# 1.98             Call Of Duty: Modern Warfare  57.0   11.0  2021.0
# 2.27             Call Of Duty: Modern Warfare  29.0    1.0  2021.0
# 2.29             Call Of Duty: Modern Warfare  30.0    2.0  2021.0
# 2.32             Call Of Duty: Modern Warfare  30.0    6.0  2021.0
#
#                                                Hours_watched  Peak_viewers  \
# Avg_viewer_ratio Game
# 1.95             Call Of Duty: Modern Warfare      3139259.0       33616.0
# 1.98             Call Of Duty: Modern Warfare      4140782.0       29529.0
# 2.27             Call Of Duty: Modern Warfare     11218009.0       41712.0
# 2.29             Call Of Duty: Modern Warfare     10918065.0       48998.0
# 2.32             Call Of Duty: Modern Warfare      7963312.0       63836.0
#
#                                                Peak_channels  Streamers  \
# Avg_viewer_ratio Game
# 1.95             Call Of Duty: Modern Warfare         5541.0   138571.0
# 1.98             Call Of Duty: Modern Warfare         6219.0   164882.0
# 2.27             Call Of Duty: Modern Warfare        13547.0   362233.0
# 2.29             Call Of Duty: Modern Warfare        13827.0   363852.0
# 2.32             Call Of Duty: Modern Warfare         9033.0   260049.0
#
#                                                Avg_viewers  Avg_channels  \
# Avg_viewer_ratio Game
# 1.95             Call Of Duty: Modern Warfare       4225.0        2170.0
# 1.98             Call Of Duty: Modern Warfare       5759.0        2906.0
# 2.27             Call Of Duty: Modern Warfare      15098.0        6659.0
# 2.29             Call Of Duty: Modern Warfare      16271.0        7096.0
# 2.32             Call Of Duty: Modern Warfare      11075.0        4780.0
#
#                                                Lenght Game Name
# Avg_viewer_ratio Game
# 1.95             Call Of Duty: Modern Warfare              28.0
# 1.98             Call Of Duty: Modern Warfare              28.0
# 2.27             Call Of Duty: Modern Warfare              28.0
# 2.29             Call Of Duty: Modern Warfare              28.0
# 2.32             Call Of Duty: Modern Warfare              28.0

# %% [markdown]
# 10 Транспонировать таблицу (или создать новую другую) с MultiIndex

# %%
multi_indexed_data.T.head()
# Out:
# Game             .hack//G.U. Last Recode 60 Parsecs! 60 Seconds!            \
# Avg_viewer_ratio                  4.12        283.71      195.93    217.64
# Rank                               199.0       109.0       147.0     199.0
# Month                               11.0         9.0         8.0      11.0
# Year                              2017.0      2018.0      2019.0    2016.0
# Hours_watched                   145350.0    529688.0    402052.0  109473.0
# Peak_viewers                      1222.0     31960.0     23955.0    5297.0
#
# Game                                                                          \
# Avg_viewer_ratio    255.12    270.24    306.93    366.42    374.23    388.04
# Rank                 194.0     186.0     182.0     139.0      54.0     119.0
# Month                  8.0      12.0      11.0       7.0       8.0       3.0
# Year                2018.0    2017.0    2017.0    2019.0    2016.0    2017.0
# Hours_watched     222209.0  180788.0  179250.0  435311.0  772786.0  263482.0
# Peak_viewers       18245.0   23476.0   10458.0   41049.0   56904.0   31311.0
#
# Game              ... skribbl.io some some convenience store  \
# Avg_viewer_ratio  ...     46.57                       73.22
# Rank              ...      175.0                       200.0
# Month             ...       12.0                         1.0
# Year              ...     2019.0                      2020.0
# Hours_watched     ...   327346.0                    342876.0
# Peak_viewers      ...    53093.0                      9903.0
#
# Game             theHunter: Call of the Wild                                \
# Avg_viewer_ratio                      19.34     19.52     27.36     29.80
# Rank                                   169.0     163.0     125.0     142.0
# Month                                    4.5      12.0      10.0      11.0
# Year                                  2018.0    2017.0    2017.0    2017.0
# Hours_watched                       254040.0  224528.0  307138.0  275393.0
# Peak_viewers                         11247.5    5978.0   36876.0   13279.0
#
# Game
# Avg_viewer_ratio    39.69     42.86     43.20     60.47
# Rank                 163.0     101.0     182.0     111.0
# Month                  7.0       2.0       5.0       4.0
# Year                2018.0    2017.0    2017.0    2017.0
# Hours_watched     342667.0  393535.0  151758.0  318876.0
# Peak_viewers       27600.0   38608.0   46646.0   45891.0
#
# [5 rows x 14247 columns]

# %% [markdown]
# 11 Удалить один из уровней индекса или добавить новый уровень индекса (можно инициализированный константой)

# %%
multi_indexed_data.swaplevel().sort_index().head()
# Out:
#                                                Rank  Month    Year  \
# Avg_viewer_ratio Game
# 1.95             Call Of Duty: Modern Warfare  71.0   12.0  2021.0
# 1.98             Call Of Duty: Modern Warfare  57.0   11.0  2021.0
# 2.27             Call Of Duty: Modern Warfare  29.0    1.0  2021.0
# 2.29             Call Of Duty: Modern Warfare  30.0    2.0  2021.0
# 2.32             Call Of Duty: Modern Warfare  30.0    6.0  2021.0
#
#                                                Hours_watched  Peak_viewers  \
# Avg_viewer_ratio Game
# 1.95             Call Of Duty: Modern Warfare      3139259.0       33616.0
# 1.98             Call Of Duty: Modern Warfare      4140782.0       29529.0
# 2.27             Call Of Duty: Modern Warfare     11218009.0       41712.0
# 2.29             Call Of Duty: Modern Warfare     10918065.0       48998.0
# 2.32             Call Of Duty: Modern Warfare      7963312.0       63836.0
#
#                                                Peak_channels  Streamers  \
# Avg_viewer_ratio Game
# 1.95             Call Of Duty: Modern Warfare         5541.0   138571.0
# 1.98             Call Of Duty: Modern Warfare         6219.0   164882.0
# 2.27             Call Of Duty: Modern Warfare        13547.0   362233.0
# 2.29             Call Of Duty: Modern Warfare        13827.0   363852.0
# 2.32             Call Of Duty: Modern Warfare         9033.0   260049.0
#
#                                                Avg_viewers  Avg_channels  \
# Avg_viewer_ratio Game
# 1.95             Call Of Duty: Modern Warfare       4225.0        2170.0
# 1.98             Call Of Duty: Modern Warfare       5759.0        2906.0
# 2.27             Call Of Duty: Modern Warfare      15098.0        6659.0
# 2.29             Call Of Duty: Modern Warfare      16271.0        7096.0
# 2.32             Call Of Duty: Modern Warfare      11075.0        4780.0
#
#                                                Lenght Game Name
# Avg_viewer_ratio Game
# 1.95             Call Of Duty: Modern Warfare              28.0
# 1.98             Call Of Duty: Modern Warfare              28.0
# 2.27             Call Of Duty: Modern Warfare              28.0
# 2.29             Call Of Duty: Modern Warfare              28.0
# 2.32             Call Of Duty: Modern Warfare              28.0

# %% [markdown]
# 12 Продемонстировать работу .merge

# %%
# по строкам и столбцам в указанном диапазоне
df_a = df.iloc[:, 0:3]
df_a
# Out:
#        Rank                              Game  Month
# 0         1                 League of Legends      1
# 1         2  Counter-Strike: Global Offensive      1
# 2         3                            Dota 2      1
# 3         4                       Hearthstone      1
# 4         5       Call of Duty: Black Ops III      1
# ...     ...                               ...    ...
# 14395   196                       Garry's Mod     12
# 14396   197  Call of Duty: Black Ops Cold War     12
# 14397   198                             Noita     12
# 14398   199                 Pro Soccer Online     12
# 14399   200       Pok<U+00E9>mon Sword/Shield     12
#
# [14400 rows x 3 columns]

# %%
df_b = df.iloc[:, 2:6]
df_b
# Out:
#        Month  Year  Hours_watched Hours_Streamed
# 0          1  2016       94377226  1362044 hours
# 1          1  2016       47832863   830105 hours
# 2          1  2016       45185893   433397 hours
# 3          1  2016       39936159   235903 hours
# 4          1  2016       16153057  1151578 hours
# ...      ...   ...            ...            ...
# 14395     12  2021         630902    21753 hours
# 14396     12  2021         622497   223641 hours
# 14397     12  2021         620983    13935 hours
# 14398     12  2021         619859      606 hours
# 14399     12  2021         615725    42291 hours
#
# [14400 rows x 4 columns]

# %%
df_merge=df_a.merge(df_b)
df_merge
# Out:
#           Rank                         Game  Month  Year  Hours_watched  \
# 0            1            League of Legends      1  2016       94377226
# 1            1            League of Legends      1  2016       47832863
# 2            1            League of Legends      1  2016       45185893
# 3            1            League of Legends      1  2016       39936159
# 4            1            League of Legends      1  2016       16153057
# ...        ...                          ...    ...   ...            ...
# 17279995   200  Pok<U+00E9>mon Sword/Shield     12  2021         630902
# 17279996   200  Pok<U+00E9>mon Sword/Shield     12  2021         622497
# 17279997   200  Pok<U+00E9>mon Sword/Shield     12  2021         620983
# 17279998   200  Pok<U+00E9>mon Sword/Shield     12  2021         619859
# 17279999   200  Pok<U+00E9>mon Sword/Shield     12  2021         615725
#
#          Hours_Streamed
# 0         1362044 hours
# 1          830105 hours
# 2          433397 hours
# 3          235903 hours
# 4         1151578 hours
# ...                 ...
# 17279995    21753 hours
# 17279996   223641 hours
# 17279997    13935 hours
# 17279998      606 hours
# 17279999    42291 hours
#
# [17280000 rows x 6 columns]

# %% [markdown]
# 13 Продемонстрировать работу с .concat или append

# %%
df_append=df_a.append(df_b)
df_append
# Out:
#        Rank                              Game  Month    Year  Hours_watched  \
# 0       1.0                 League of Legends      1     NaN            NaN
# 1       2.0  Counter-Strike: Global Offensive      1     NaN            NaN
# 2       3.0                            Dota 2      1     NaN            NaN
# 3       4.0                       Hearthstone      1     NaN            NaN
# 4       5.0       Call of Duty: Black Ops III      1     NaN            NaN
# ...     ...                               ...    ...     ...            ...
# 14395   NaN                               NaN     12  2021.0       630902.0
# 14396   NaN                               NaN     12  2021.0       622497.0
# 14397   NaN                               NaN     12  2021.0       620983.0
# 14398   NaN                               NaN     12  2021.0       619859.0
# 14399   NaN                               NaN     12  2021.0       615725.0
#
#       Hours_Streamed
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 14395    21753 hours
# 14396   223641 hours
# 14397    13935 hours
# 14398      606 hours
# 14399    42291 hours
#
# [28800 rows x 6 columns]

# %%
pd.concat([df_a, df_b], axis=0, ignore_index=True)
# Out:
#        Rank                              Game  Month    Year  Hours_watched  \
# 0       1.0                 League of Legends      1     NaN            NaN
# 1       2.0  Counter-Strike: Global Offensive      1     NaN            NaN
# 2       3.0                            Dota 2      1     NaN            NaN
# 3       4.0                       Hearthstone      1     NaN            NaN
# 4       5.0       Call of Duty: Black Ops III      1     NaN            NaN
# ...     ...                               ...    ...     ...            ...
# 28795   NaN                               NaN     12  2021.0       630902.0
# 28796   NaN                               NaN     12  2021.0       622497.0
# 28797   NaN                               NaN     12  2021.0       620983.0
# 28798   NaN                               NaN     12  2021.0       619859.0
# 28799   NaN                               NaN     12  2021.0       615725.0
#
#       Hours_Streamed
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 28795    21753 hours
# 28796   223641 hours
# 28797    13935 hours
# 28798      606 hours
# 28799    42291 hours
#
# [28800 rows x 6 columns]

# %% [markdown]
# 14 Проитерировать dataframe построчно .iterrows(). Выполните что-то имеющее смысл внутри цикла

# %%
for i, (index, row) in enumerate(df.iterrows()):
    if row['Game'] == 'Diablo III':
        print(f'Diablo III {i}th row')
# Out:
# Diablo III 11th row
# Diablo III 224th row
# Diablo III 455th row
# Diablo III 639th row
# Diablo III 824th row
# Diablo III 1049th row
# Diablo III 1284th row
# Diablo III 1429th row
# Diablo III 1699th row
# Diablo III 1874th row
# Diablo III 2071th row
# Diablo III 2291th row
# Diablo III 2435th row
# Diablo III 2650th row
# Diablo III 2871th row
# Diablo III 3032th row
# Diablo III 3255th row
# Diablo III 3443th row
# Diablo III 3623th row
# Diablo III 3842th row
# Diablo III 4072th row
# Diablo III 4292th row
# Diablo III 4431th row
# Diablo III 4669th row
# Diablo III 4893th row
# Diablo III 5049th row
# Diablo III 5257th row
# Diablo III 5490th row
# Diablo III 5709th row
# Diablo III 5833th row
# Diablo III 6031th row
# Diablo III 6290th row
# Diablo III 6460th row
# Diablo III 6689th row
# Diablo III 6863th row
# Diablo III 7101th row
# Diablo III 7243th row
# Diablo III 7468th row
# Diablo III 7717th row
# Diablo III 7908th row
# Diablo III 8041th row
# Diablo III 8283th row
# Diablo III 8489th row
# Diablo III 8664th row
# Diablo III 8889th row
# Diablo III 9074th row
# Diablo III 9234th row
# Diablo III 9463th row
# Diablo III 9757th row
# Diablo III 9921th row
# Diablo III 10065th row
# Diablo III 10323th row
# Diablo III 10558th row
# Diablo III 10765th row
# Diablo III 10863th row
# Diablo III 11111th row
# Diablo III 11578th row
# Diablo III 11671th row
# Diablo III 11953th row
# Diablo III 12177th row
# Diablo III 12399th row
# Diablo III 12591th row
# Diablo III 12652th row
# Diablo III 12981th row
# Diablo III 13274th row
# Diablo III 13497th row
# Diablo III 14261th row
